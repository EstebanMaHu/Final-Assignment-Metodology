# %% [markdown]
# # Final Assignment: Metodology (CRISP-DM)

# %% [markdown]
# ## Client (Bank)

# %% [markdown]
# What are te credit cards with the highest profit?

# %% [markdown]
# ## Data Scientist

# %% [markdown]
# ### Business understanding

# %% [markdown]
# - What credit cards generate most interests and revenue?
# (Descriptive question)

# %% [markdown]
# ### Data understanding

# %% [markdown]
# - _**Because the confidential and sensitive nature of the information needed for this task, all data used must be obtained from the bank internal data bases.**_
#     1. How many customer own a credit card?
#     2. How many of each credit card available by the bank are out there?
#     3. How many time each customer use their credit card every month?
#
# - To answer these quensions we would need:
#     1. The list of every customer with a credit one or multiple credir cards;
#     2. History of use of each credit card;
#
#
# - Would be this data enough to answer the main problem?

# %% [markdown]
# ### Data preparation

# %% [markdown]
# - We will remove all duplicated, invalid or missing values. Making sure all data shares the same format to ensure confortable and smoth work.

# %% [markdown]
# ### Modeling

# %% [markdown]
# - Choosing and adapting models to find out what credit cardsm are used more often generating revenue;
# - Revealing relevant patterns and structure import to answer the main problem. What cards, in what seasons, buying what products, used by what customer profiles generatoe themost revenue.

# %% [markdown]
# ### Deployment

# %% [markdown]
# - Apply the models to new data, looking to find out if a new data set, variables or a new model are needed.

# %% [markdown]
# ## Author

# %% [markdown]
# Esteban Martinez Hurtado
